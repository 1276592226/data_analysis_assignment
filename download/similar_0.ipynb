# %%
# 引入库
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# 设置基本参数
pd.set_option('display.width', 60)

# %%
# 导入完整数据
df = pd.read_excel('../data/supermarket_data_clean_min.xlsx', sheet_name="Data")

# 过滤数据类型错误的信息所在的行
def is_number(value):
    return isinstance(value, (int, float))
def is_string(value):
    return isinstance(value, (str,))
df = df[df["Quantity"].map(lambda x: isinstance(x, (int, float)))]
df = df[df["Sub-Category"].map(is_string)]
print(df)
# Out:
#       Order Date Order Date Year Month  Order Date Year  \
# 0       1/1/2011               2011-01             2011
# 1       1/2/2011               2011-01             2011
# 2       1/3/2011               2011-01             2011
# 3       1/3/2011               2011-01             2011
# 4       1/4/2011               2011-01             2011
# ...          ...                   ...              ...
# 2559  31-12-2013               2013-12             2013
# 2560  31-12-2013               2013-12             2013
# 2561  31-12-2014               2014-12             2014
# 2562  31-12-2014               2014-12             2014
# 2563  31-12-2014               2014-12             2014
#
#       Order Date Month  Order Date Day Ship Date  \
# 0                    1               1  6/1/2011
# 1                    1               2  7/2/2011
# 2                    1               3  8/3/2011
# 3                    1               3  6/3/2011
# 4                    1               4  5/4/2011
# ...                ...             ...       ...
# 2559                12              31  7/1/2014
# 2560                12              31  2/1/2014
# 2561                12              31  7/1/2015
# 2562                12              31  5/1/2015
# 2563                12              31  2/1/2015
#
#       Ship Date Year  Ship Date Month  Ship Date Day  \
# 0               2011                6              1
# 1               2011                7              2
# 2               2011                8              3
# 3               2011                6              3
# 4               2011                5              4
# ...              ...              ...            ...
# 2559            2014                7              1
# 2560            2014                2              1
# 2561            2015                7              1
# 2562            2015                5              1
# 2563            2015                2              1
#
#            Ship Mode  ... Sub-Category  \
# 0     Standard Class  ...      Storage
# 1     Standard Class  ...      Binders
# 2     Standard Class  ...          Art
# 3     Standard Class  ...          Art
# 4       Second Class  ...       Phones
# ...              ...  ...          ...
# 2559  Standard Class  ...      Storage
# 2560    Second Class  ...      Binders
# 2561  Standard Class  ...  Accessories
# 2562    Second Class  ...          Art
# 2563    Second Class  ...       Labels
#
#                                 Product Name    Sales  \
# 0                        Tenex Lockers, Blue    408.3
# 1         Acco Hole Reinforcements, Recycled    21.06
# 2                    BIC Markers, Easy-Erase    106.8
# 3                  Sanford Pens, Fluorescent    37.08
# 4        Motorola Audio Dock, with Caller ID  138.696
# ...                                      ...      ...
# 2559                   Tenex Box, Industrial    33.96
# 2560            Wilson Jones Binder, Economy    13.02
# 2561       Enermax Numeric Keypad, Bluetooth   171.99
# 2562       BIC Pencil Sharpener, Fluorescent    30.27
# 2563  Hon Color Coded Labels, 5000 Label Set     26.4
#
#      Quantity Discount  Profit Shipping Cost  \
# 0         2.0      0.0  106.14         35.46
# 1         3.0      0.0   10.53          1.86
# 2         4.0      0.0   29.88         16.48
# 3         3.0      0.0   10.35          3.55
# 4         2.0      0.4 -25.464          20.4
# ...       ...      ...     ...           ...
# 2559      2.0      0.0   15.96          4.17
# 2560      1.0      0.0    4.02          0.14
# 2561      3.0      0.0    6.84         16.66
# 2562      2.0      0.5   -9.69          4.46
# 2563      3.0      0.0   12.36          0.35
#
#      Order Priority Unnamed: 24 Unnamed: 25
# 0            Medium         NaN         NaN
# 1            Medium         NaN         NaN
# 2               Low         NaN         NaN
# 3              High         NaN         NaN
# 4            Medium         NaN         NaN
# ...             ...         ...         ...
# 2559            Low         NaN         NaN
# 2560         Medium         NaN         NaN
# 2561         Medium         NaN         NaN
# 2562           High         NaN         NaN
# 2563         Medium         NaN         NaN
#
# [2559 rows x 31 columns]

# %%
# 查看每个用户的订单数量 [与下方代码无关]
cc = df.groupby("Customer Name").agg({"count"})
print(cc)
# Out:
#                    Order Date Order Date Year Month  \
#                         count                 count
# Customer Name
# Aaron Bergman               5                     5
# Aaron Hawkins               4                     4
# Aaron Smayling              2                     2
# Adam Bellavance             4                     4
# Adam Hart                   3                     3
# ...                       ...                   ...
# Xylona Preis                7                     7
# Yana Sorensen               3                     3
# Yoseph Carroll              2                     2
# Zuschuss Carroll            3                     3
# Zuschuss Donatelli          1                     1
#
#                    Order Date Year Order Date Month  \
#                              count            count
# Customer Name
# Aaron Bergman                    5                5
# Aaron Hawkins                    4                4
# Aaron Smayling                   2                2
# Adam Bellavance                  4                4
# Adam Hart                        3                3
# ...                            ...              ...
# Xylona Preis                     7                7
# Yana Sorensen                    3                3
# Yoseph Carroll                   2                2
# Zuschuss Carroll                 3                3
# Zuschuss Donatelli               1                1
#
#                    Order Date Day Ship Date  \
#                             count     count
# Customer Name
# Aaron Bergman                   5         5
# Aaron Hawkins                   4         4
# Aaron Smayling                  2         2
# Adam Bellavance                 4         4
# Adam Hart                       3         3
# ...                           ...       ...
# Xylona Preis                    7         7
# Yana Sorensen                   3         3
# Yoseph Carroll                  2         2
# Zuschuss Carroll                3         3
# Zuschuss Donatelli              1         1
#
#                    Ship Date Year Ship Date Month  \
#                             count           count
# Customer Name
# Aaron Bergman                   5               5
# Aaron Hawkins                   4               4
# Aaron Smayling                  2               2
# Adam Bellavance                 4               4
# Adam Hart                       3               3
# ...                           ...             ...
# Xylona Preis                    7               7
# Yana Sorensen                   3               3
# Yoseph Carroll                  2               2
# Zuschuss Carroll                3               3
# Zuschuss Donatelli              1               1
#
#                    Ship Date Day Ship Mode  ...  \
#                            count     count  ...
# Customer Name                               ...
# Aaron Bergman                  5         5  ...
# Aaron Hawkins                  4         4  ...
# Aaron Smayling                 2         2  ...
# Adam Bellavance                4         4  ...
# Adam Hart                      3         3  ...
# ...                          ...       ...  ...
# Xylona Preis                   7         7  ...
# Yana Sorensen                  3         3  ...
# Yoseph Carroll                 2         2  ...
# Zuschuss Carroll               3         3  ...
# Zuschuss Donatelli             1         1  ...
#
#                    Sub-Category Product Name Sales  \
#                           count        count count
# Customer Name
# Aaron Bergman                 5            5     5
# Aaron Hawkins                 4            4     4
# Aaron Smayling                2            2     2
# Adam Bellavance               4            4     4
# Adam Hart                     3            3     3
# ...                         ...          ...   ...
# Xylona Preis                  7            7     7
# Yana Sorensen                 3            3     3
# Yoseph Carroll                2            2     2
# Zuschuss Carroll              3            3     3
# Zuschuss Donatelli            1            1     1
#
#                    Quantity Discount Profit Shipping Cost  \
#                       count    count  count         count
# Customer Name
# Aaron Bergman             5        5      5             5
# Aaron Hawkins             4        4      4             4
# Aaron Smayling            2        2      2             2
# Adam Bellavance           4        4      4             4
# Adam Hart                 3        3      3             3
# ...                     ...      ...    ...           ...
# Xylona Preis              7        7      7             7
# Yana Sorensen             3        3      3             3
# Yoseph Carroll            2        2      2             2
# Zuschuss Carroll          3        3      3             3
# Zuschuss Donatelli        1        1      1             1
#
#                    Order Priority Unnamed: 24 Unnamed: 25
#                             count       count       count
# Customer Name
# Aaron Bergman                   5           0           0
# Aaron Hawkins                   4           0           0
# Aaron Smayling                  2           0           0
# Adam Bellavance                 4           0           0
# Adam Hart                       3           0           0
# ...                           ...         ...         ...
# Xylona Preis                    7           0           0
# Yana Sorensen                   3           0           0
# Yoseph Carroll                  2           0           0
# Zuschuss Carroll                3           0           0
# Zuschuss Donatelli              1           0           0
#
# [771 rows x 30 columns]

# %%
# 筛选指定用户的有效信息 [与下方代码无关]

u1 = df[df['Customer Name'] == 'Aaron Bergman'][['Sub-Category', 'Sales', 'Quantity', 'Order Date']]
print(u1)
# Out:
#      Sub-Category     Sales  Quantity  Order Date
# 627        Phones    221.98       2.0  11/11/2013
# 1175  Accessories    225.24       3.0  15-01-2014
# 1255       Chairs     610.6       2.0  15-12-2014
# 2364  Furnishings  561.5379       7.0  28-12-2012
# 2366      Binders   23.3064       4.0  28-12-2012

# %%
# 获取指定用户在各类别上的购买次数作为特征 [与下方代码无关]
u1sc = u1[["Quantity", 'Sub-Category']].groupby('Sub-Category').agg({'sum'})
print(u1sc)
# Out:
#              Quantity
#                   sum
# Sub-Category
# Accessories       3.0
# Binders           4.0
# Chairs            2.0
# Furnishings       7.0
# Phones            2.0

# %%
# 获取所有类别的总购买次数
sc = df[['Sub-Category', 'Quantity']].groupby('Sub-Category').agg({'sum'})
sc.columns = ['All']
print(sc)
# Out:
#                                                     All
# Sub-Category
# Accessories                                     500.000
# Acme Box Cutter, Easy Grip                        0.000
# Advantus Door Stop, Durable                       0.000
# Appliances                                      273.000
# Art                                             830.000
# Avery Binder, Recycled                            0.000
# BIC Markers, Fluorescent                          0.400
# BIC Sketch Pad, Water Color                       0.000
# Binders                                         964.000
# Bookcases                                       392.000
# Chairs                                          617.000
# Copiers                                         369.000
# Eaton Parchment Paper, Premium                    0.000
# Eldon Clock, Durable                              0.400
# Eldon Trays, Industrial                           0.400
# Elite Shears, Easy Grip                           0.000
# Envelopes                                       501.000
# Fasteners                                       426.000
# Fiskars Trimmer, Easy Grip                        0.400
# Furnishings                                     483.000
# Green Bar Computer Printout Paper, 8.5 x 11       0.000
# Green Bar Message Books, Multicolor               0.000
# HP Fax and Copier, Color                          0.002
# Harbour Creations Removable Labels, Adjustable    0.000
# Jiffy Interoffice Envelope, Security-Tint         0.000
# Labels                                          413.000
# Machines                                        206.000
# Memorex Keyboard, USB                             0.000
# Memorex Memory Card, Bluetooth                    0.000
# Motorola Office Telephone, with Caller ID         0.600
# Novimex Chairmat, Adjustable                      0.000
# Novimex Executive Leather Armchair, Adjustable    0.000
# Okidata Printer, Wireless                         0.000
# Paper                                           627.000
# Phones                                          632.000
# Sanford Pens, Water Color                         0.000
# Sharp Fax Machine, Digital                        0.602
# Sharp Fax and Copier, Color                       0.402
# Smead Box, Industrial                             0.000
# Smead Color Coded Labels, Alphabetical            0.000
# Stockwell Thumb Tacks, Bulk Pack                  0.000
# Storage                                         990.000
# Supplies                                        392.000
# Tables                                          146.000

# %%
# 指定用户 在每个类别上的 累计购买次数
user = "Aaron Bergman"
u1 = df[df['Customer Name'] == user][['Sub-Category', 'Sales', 'Quantity', 'Order Date']]
u1sc = u1[["Quantity", 'Sub-Category']].groupby('Sub-Category').agg({'sum'})
u1sc.columns = [user]
print(u1sc)
# Out:
#               Aaron Bergman
# Sub-Category
# Accessories             3.0
# Binders                 4.0
# Chairs                  2.0
# Furnishings             7.0
# Phones                  2.0

# %%
# 获取各个用户的购买次数特征并拼接至一张表上
users = ["Aaron Bergman", "Aaron Hawkins", "Aaron Smayling", "Adam Bellavance"]
for user in users:
    u1 = df[df['Customer Name'] == user][['Sub-Category', 'Sales', 'Quantity', 'Order Date']]
    u1sc = u1[["Quantity", 'Sub-Category']].groupby('Sub-Category').agg({'sum'})
    u1sc.columns = [user]
    sc = pd.concat([sc, u1sc], axis=1)
sc = sc.fillna(0)
print(sc)
# Out:
#                                                     All  \
# Sub-Category
# Accessories                                     500.000
# Acme Box Cutter, Easy Grip                        0.000
# Advantus Door Stop, Durable                       0.000
# Appliances                                      273.000
# Art                                             830.000
# Avery Binder, Recycled                            0.000
# BIC Markers, Fluorescent                          0.400
# BIC Sketch Pad, Water Color                       0.000
# Binders                                         964.000
# Bookcases                                       392.000
# Chairs                                          617.000
# Copiers                                         369.000
# Eaton Parchment Paper, Premium                    0.000
# Eldon Clock, Durable                              0.400
# Eldon Trays, Industrial                           0.400
# Elite Shears, Easy Grip                           0.000
# Envelopes                                       501.000
# Fasteners                                       426.000
# Fiskars Trimmer, Easy Grip                        0.400
# Furnishings                                     483.000
# Green Bar Computer Printout Paper, 8.5 x 11       0.000
# Green Bar Message Books, Multicolor               0.000
# HP Fax and Copier, Color                          0.002
# Harbour Creations Removable Labels, Adjustable    0.000
# Jiffy Interoffice Envelope, Security-Tint         0.000
# Labels                                          413.000
# Machines                                        206.000
# Memorex Keyboard, USB                             0.000
# Memorex Memory Card, Bluetooth                    0.000
# Motorola Office Telephone, with Caller ID         0.600
# Novimex Chairmat, Adjustable                      0.000
# Novimex Executive Leather Armchair, Adjustable    0.000
# Okidata Printer, Wireless                         0.000
# Paper                                           627.000
# Phones                                          632.000
# Sanford Pens, Water Color                         0.000
# Sharp Fax Machine, Digital                        0.602
# Sharp Fax and Copier, Color                       0.402
# Smead Box, Industrial                             0.000
# Smead Color Coded Labels, Alphabetical            0.000
# Stockwell Thumb Tacks, Bulk Pack                  0.000
# Storage                                         990.000
# Supplies                                        392.000
# Tables                                          146.000
#
#                                                 Aaron Bergman  \
# Sub-Category
# Accessories                                               3.0
# Acme Box Cutter, Easy Grip                                0.0
# Advantus Door Stop, Durable                               0.0
# Appliances                                                0.0
# Art                                                       0.0
# Avery Binder, Recycled                                    0.0
# BIC Markers, Fluorescent                                  0.0
# BIC Sketch Pad, Water Color                               0.0
# Binders                                                   4.0
# Bookcases                                                 0.0
# Chairs                                                    2.0
# Copiers                                                   0.0
# Eaton Parchment Paper, Premium                            0.0
# Eldon Clock, Durable                                      0.0
# Eldon Trays, Industrial                                   0.0
# Elite Shears, Easy Grip                                   0.0
# Envelopes                                                 0.0
# Fasteners                                                 0.0
# Fiskars Trimmer, Easy Grip                                0.0
# Furnishings                                               7.0
# Green Bar Computer Printout Paper, 8.5 x 11               0.0
# Green Bar Message Books, Multicolor                       0.0
# HP Fax and Copier, Color                                  0.0
# Harbour Creations Removable Labels, Adjustable            0.0
# Jiffy Interoffice Envelope, Security-Tint                 0.0
# Labels                                                    0.0
# Machines                                                  0.0
# Memorex Keyboard, USB                                     0.0
# Memorex Memory Card, Bluetooth                            0.0
# Motorola Office Telephone, with Caller ID                 0.0
# Novimex Chairmat, Adjustable                              0.0
# Novimex Executive Leather Armchair, Adjustable            0.0
# Okidata Printer, Wireless                                 0.0
# Paper                                                     0.0
# Phones                                                    2.0
# Sanford Pens, Water Color                                 0.0
# Sharp Fax Machine, Digital                                0.0
# Sharp Fax and Copier, Color                               0.0
# Smead Box, Industrial                                     0.0
# Smead Color Coded Labels, Alphabetical                    0.0
# Stockwell Thumb Tacks, Bulk Pack                          0.0
# Storage                                                   0.0
# Supplies                                                  0.0
# Tables                                                    0.0
#
#                                                 Aaron Hawkins  \
# Sub-Category
# Accessories                                               0.0
# Acme Box Cutter, Easy Grip                                0.0
# Advantus Door Stop, Durable                               0.0
# Appliances                                                0.0
# Art                                                       0.0
# Avery Binder, Recycled                                    0.0
# BIC Markers, Fluorescent                                  0.0
# BIC Sketch Pad, Water Color                               0.0
# Binders                                                   1.0
# Bookcases                                                 0.0
# Chairs                                                    0.0
# Copiers                                                   0.0
# Eaton Parchment Paper, Premium                            0.0
# Eldon Clock, Durable                                      0.0
# Eldon Trays, Industrial                                   0.0
# Elite Shears, Easy Grip                                   0.0
# Envelopes                                                 0.0
# Fasteners                                                 0.0
# Fiskars Trimmer, Easy Grip                                0.0
# Furnishings                                               0.0
# Green Bar Computer Printout Paper, 8.5 x 11               0.0
# Green Bar Message Books, Multicolor                       0.0
# HP Fax and Copier, Color                                  0.0
# Harbour Creations Removable Labels, Adjustable            0.0
# Jiffy Interoffice Envelope, Security-Tint                 0.0
# Labels                                                    1.0
# Machines                                                  0.0
# Memorex Keyboard, USB                                     0.0
# Memorex Memory Card, Bluetooth                            0.0
# Motorola Office Telephone, with Caller ID                 0.0
# Novimex Chairmat, Adjustable                              0.0
# Novimex Executive Leather Armchair, Adjustable            0.0
# Okidata Printer, Wireless                                 0.0
# Paper                                                     0.0
# Phones                                                    0.0
# Sanford Pens, Water Color                                 0.0
# Sharp Fax Machine, Digital                                0.0
# Sharp Fax and Copier, Color                               0.0
# Smead Box, Industrial                                     0.0
# Smead Color Coded Labels, Alphabetical                    0.0
# Stockwell Thumb Tacks, Bulk Pack                          0.0
# Storage                                                   1.0
# Supplies                                                  5.0
# Tables                                                    0.0
#
#                                                 Aaron Smayling  \
# Sub-Category
# Accessories                                                2.0
# Acme Box Cutter, Easy Grip                                 0.0
# Advantus Door Stop, Durable                                0.0
# Appliances                                                 0.0
# Art                                                        0.0
# Avery Binder, Recycled                                     0.0
# BIC Markers, Fluorescent                                   0.0
# BIC Sketch Pad, Water Color                                0.0
# Binders                                                    0.0
# Bookcases                                                  0.0
# Chairs                                                     0.0
# Copiers                                                    0.0
# Eaton Parchment Paper, Premium                             0.0
# Eldon Clock, Durable                                       0.0
# Eldon Trays, Industrial                                    0.0
# Elite Shears, Easy Grip                                    0.0
# Envelopes                                                  0.0
# Fasteners                                                  0.0
# Fiskars Trimmer, Easy Grip                                 0.0
# Furnishings                                                0.0
# Green Bar Computer Printout Paper, 8.5 x 11                0.0
# Green Bar Message Books, Multicolor                        0.0
# HP Fax and Copier, Color                                   0.0
# Harbour Creations Removable Labels, Adjustable             0.0
# Jiffy Interoffice Envelope, Security-Tint                  0.0
# Labels                                                     0.0
# Machines                                                   0.0
# Memorex Keyboard, USB                                      0.0
# Memorex Memory Card, Bluetooth                             0.0
# Motorola Office Telephone, with Caller ID                  0.0
# Novimex Chairmat, Adjustable                               0.0
# Novimex Executive Leather Armchair, Adjustable             0.0
# Okidata Printer, Wireless                                  0.0
# Paper                                                      0.0
# Phones                                                     0.0
# Sanford Pens, Water Color                                  0.0
# Sharp Fax Machine, Digital                                 0.0
# Sharp Fax and Copier, Color                                0.0
# Smead Box, Industrial                                      0.0
# Smead Color Coded Labels, Alphabetical                     0.0
# Stockwell Thumb Tacks, Bulk Pack                           0.0
# Storage                                                    1.0
# Supplies                                                   0.0
# Tables                                                     0.0
#
#                                                 Adam Bellavance
# Sub-Category
# Accessories                                                 3.0
# Acme Box Cutter, Easy Grip                                  0.0
# Advantus Door Stop, Durable                                 0.0
# Appliances                                                  4.0
# Art                                                         0.0
# Avery Binder, Recycled                                      0.0
# BIC Markers, Fluorescent                                    0.0
# BIC Sketch Pad, Water Color                                 0.0
# Binders                                                     2.0
# Bookcases                                                   0.0
# Chairs                                                      0.0
# Copiers                                                     0.0
# Eaton Parchment Paper, Premium                              0.0
# Eldon Clock, Durable                                        0.0
# Eldon Trays, Industrial                                     0.0
# Elite Shears, Easy Grip                                     0.0
# Envelopes                                                   0.0
# Fasteners                                                   0.0
# Fiskars Trimmer, Easy Grip                                  0.0
# Furnishings                                                 0.0
# Green Bar Computer Printout Paper, 8.5 x 11                 0.0
# Green Bar Message Books, Multicolor                         0.0
# HP Fax and Copier, Color                                    0.0
# Harbour Creations Removable Labels, Adjustable              0.0
# Jiffy Interoffice Envelope, Security-Tint                   0.0
# Labels                                                      0.0
# Machines                                                    0.0
# Memorex Keyboard, USB                                       0.0
# Memorex Memory Card, Bluetooth                              0.0
# Motorola Office Telephone, with Caller ID                   0.0
# Novimex Chairmat, Adjustable                                0.0
# Novimex Executive Leather Armchair, Adjustable              0.0
# Okidata Printer, Wireless                                   0.0
# Paper                                                       3.0
# Phones                                                      0.0
# Sanford Pens, Water Color                                   0.0
# Sharp Fax Machine, Digital                                  0.0
# Sharp Fax and Copier, Color                                 0.0
# Smead Box, Industrial                                       0.0
# Smead Color Coded Labels, Alphabetical                      0.0
# Stockwell Thumb Tacks, Bulk Pack                            0.0
# Storage                                                     0.0
# Supplies                                                    0.0
# Tables                                                      0.0

# %%
# 生成表格每列之间的相似度情况
similar = sc.corr(method = 'pearson', min_periods=1)
print(similar)
# Out:
#                       All  Aaron Bergman  Aaron Hawkins  \
# All              1.000000       0.460703       0.276046
# Aaron Bergman    0.460703       1.000000       0.016339
# Aaron Hawkins    0.276046       0.016339       1.000000
# Aaron Smayling   0.330839       0.252276       0.040287
# Adam Bellavance  0.354117       0.237492      -0.005988
#
#                  Aaron Smayling  Adam Bellavance
# All                    0.330839         0.354117
# Aaron Bergman          0.252276         0.237492
# Aaron Hawkins          0.040287        -0.005988
# Aaron Smayling         1.000000         0.401543
# Adam Bellavance        0.401543         1.000000

# %%
# 筛选出与指定用户最相似的用户
name = "Aaron Bergman"
us = similar[[name]]
us = us.drop('All')
us = us.drop(name)
similar_user = us.iloc[us[name].argmax()].index.values[0]
print(similar_user)
# Out:
# Aaron Bergman

# %%
# 获取最相似的用户最喜欢的商品
suf = sc[[similar_user]]
line = suf.iloc[suf[similar_user].argmax()]
print(line)
# Out:
# Aaron Bergman    7.0
# Name: Furnishings, dtype: float64

# %%
# 学生可自行拓展 获取最相似的几个用户喜欢的几件商品等
